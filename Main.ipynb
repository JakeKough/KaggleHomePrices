# %% [markdown]
# Import Packages to be used

# %%
import pandas as pd
import sklearn
import numpy as np

# %% [markdown]
# read data

# %%
print("---------------------Read Data-----------------------")
train_data_full = pd.read_csv("train.csv")
test_data_full = pd.read_csv("test.csv")
print("---Training Data---")
print(train_data_full.head())
print("\n---Testing Data---")
print(test_data_full.head())
# Out:
# ---------------------Read Data-----------------------
# ---Training Data---
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]
#
# ---Testing Data---
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# Drop rows where the value to predict (Sales Price) is null

# %%
train_data_full.dropna(axis=0, subset= ['SalePrice'], inplace = True)

# %% [markdown]
# Seperate Features from Target prediction

# %%
y = train_data_full['SalePrice']
X = train_data_full.drop(['SalePrice'],axis = 1)

# %% [markdown]
# Split Test dataset test and validation sets for training

# %%
from sklearn.model_selection import train_test_split

train_x,val_x,train_y,val_y = train_test_split(X,y,train_size = .8, test_size = .2, random_state = 1)
train_x.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 921    922          90       RL         67.0     8777   Pave   NaN      Reg
# 520    521         190       RL         60.0    10800   Pave  Grvl      Reg
# 401    402          20       RL         65.0     8767   Pave   NaN      IR1
# 280    281          60       RL         82.0    11287   Pave   NaN      Reg
# 1401  1402          60       RL         62.0     7415   Pave   NaN      IR1
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 921          Lvl    AllPub  ...           0        0    NaN  GdPrv
# 520          Lvl    AllPub  ...           0        0    NaN    NaN
# 401          Lvl    AllPub  ...           0        0    NaN    NaN
# 280          Lvl    AllPub  ...           0        0    NaN    NaN
# 1401         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 921          NaN       0      9    2008        WD         Normal
# 520          NaN       0      8    2008        WD         Normal
# 401          NaN       0      7    2006       New        Partial
# 280          NaN       0      1    2007        WD         Normal
# 1401         NaN       0      4    2008        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# investigate the dataset

# %%
def investigate(df):
    print("---columns---")
    print(df.columns)
    print("---describe---")
    df.describe()
    print("---shape---")
    print(df.shape)
    print("---data types---")
    print(df.dtypes)
    print("---info---")
    df.info()

# %%
investigate(train_x)
# Out:
# ---columns---
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')
# ---describe---
# ---shape---
# (1168, 80)
# ---data types---
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object
# ---info---
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 921 to 1061
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    959 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          71 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
#  17  OverallQual    1168 non-null   int64
#  18  OverallCond    1168 non-null   int64
#  19  YearBuilt      1168 non-null   int64
#  20  YearRemodAdd   1168 non-null   int64
#  21  RoofStyle      1168 non-null   object
#  22  RoofMatl       1168 non-null   object
#  23  Exterior1st    1168 non-null   object
#  24  Exterior2nd    1168 non-null   object
#  25  MasVnrType     1160 non-null   object
#  26  MasVnrArea     1160 non-null   float64
#  27  ExterQual      1168 non-null   object
#  28  ExterCond      1168 non-null   object
#  29  Foundation     1168 non-null   object
#  30  BsmtQual       1138 non-null   object
#  31  BsmtCond       1138 non-null   object
#  32  BsmtExposure   1137 non-null   object
#  33  BsmtFinType1   1138 non-null   object
#  34  BsmtFinSF1     1168 non-null   int64
#  35  BsmtFinType2   1137 non-null   object
#  36  BsmtFinSF2     1168 non-null   int64
#  37  BsmtUnfSF      1168 non-null   int64
#  38  TotalBsmtSF    1168 non-null   int64
#  39  Heating        1168 non-null   object
#  40  HeatingQC      1168 non-null   object
#  41  CentralAir     1168 non-null   object
#  42  Electrical     1167 non-null   object
#  43  1stFlrSF       1168 non-null   int64
#  44  2ndFlrSF       1168 non-null   int64
#  45  LowQualFinSF   1168 non-null   int64
#  46  GrLivArea      1168 non-null   int64
#  47  BsmtFullBath   1168 non-null   int64
#  48  BsmtHalfBath   1168 non-null   int64
#  49  FullBath       1168 non-null   int64
#  50  HalfBath       1168 non-null   int64
#  51  BedroomAbvGr   1168 non-null   int64
#  52  KitchenAbvGr   1168 non-null   int64
#  53  KitchenQual    1168 non-null   object
#  54  TotRmsAbvGrd   1168 non-null   int64
#  55  Functional     1168 non-null   object
#  56  Fireplaces     1168 non-null   int64
#  57  FireplaceQu    620 non-null    object
#  58  GarageType     1107 non-null   object
#  59  GarageYrBlt    1107 non-null   float64
#  60  GarageFinish   1107 non-null   object
#  61  GarageCars     1168 non-null   int64
#  62  GarageArea     1168 non-null   int64
#  63  GarageQual     1107 non-null   object
#  64  GarageCond     1107 non-null   object
#  65  PavedDrive     1168 non-null   object
#  66  WoodDeckSF     1168 non-null   int64
#  67  OpenPorchSF    1168 non-null   int64
#  68  EnclosedPorch  1168 non-null   int64
#  69  3SsnPorch      1168 non-null   int64
#  70  ScreenPorch    1168 non-null   int64
#  71  PoolArea       1168 non-null   int64
#  72  PoolQC         5 non-null      object
#  73  Fence          214 non-null    object
#  74  MiscFeature    44 non-null     object
#  75  MiscVal        1168 non-null   int64
#  76  MoSold         1168 non-null   int64
#  77  YrSold         1168 non-null   int64
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
# dtypes: float64(3), int64(34), object(43)
# memory usage: 739.1+ KB

# %% [markdown]
# Decide Features to keep initially and keep features in training dataset

# %%
features = ['MSSubClass','MSZoning','LotFrontage','LotArea','Street','Alley', 'Utilities', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1','BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF','LowQualFinSF', 'GrLivArea', 'FullBath',
       'HalfBath', 'KitchenQual','TotRmsAbvGrd', 'Fireplaces', 'GarageType','GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF','EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC','Fence', 'SaleType', 'SaleCondition']

def passfeatures(df,feat):
    return df[feat]

train_x = passfeatures(train_x,features)

# %%
#Engineer Fields
import math

print(train_x['GarageYrBlt'])
train_x['TotalSF'] = train_x['TotalBsmtSF'] + train_x['1stFlrSF'] + train_x['2ndFlrSF']
train_x['hasGarage'] = train_x['GarageYrBlt'].apply(lambda x: 0 if math.isnan(x) else 1)
print(train_x['hasGarage'].head(20))
# Out:
# 921        NaN
# 520        NaN
# 401     2005.0
# 280     1989.0
# 1401    2004.0
#          ...
# 715     1974.0
# 905     1954.0
# 1096       NaN
# 235     1971.0
# 1061    1994.0
# Name: GarageYrBlt, Length: 1168, dtype: float64
# 921     0
# 520     0
# 401     1
# 280     1
# 1401    1
# 131     1
# 808     1
# 1249    1
# 1083    1
# 613     0
# 215     1
# 135     1
# 634     1
# 446     1
# 625     1
# 298     1
# 1336    1
# 525     1
# 629     1
# 1283    0
# Name: hasGarage, dtype: int64

# %%
#normalize the int and float fields using min max
from sklearn.preprocessing import MinMaxScaler

print(train_x.head())
number_fields = []
for col in train_x:
    if train_x.dtypes[col] in ["int64","float64"]:
        number_fields.append(col)

print(number_fields)

scaler = MinMaxScaler()
train_x[number_fields] = scaler.fit_transform(train_x[number_fields])
print(train_x.head())
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 921           90       RL         67.0     8777   Pave   NaN    AllPub
# 520          190       RL         60.0    10800   Pave  Grvl    AllPub
# 401           20       RL         65.0     8767   Pave   NaN    AllPub
# 280           60       RL         82.0    11287   Pave   NaN    AllPub
# 1401          60       RL         62.0     7415   Pave   NaN    AllPub
#
#      BldgType HouseStyle  OverallQual  ...  EnclosedPorch  3SsnPorch  \
# 921    Duplex     1.5Fin            5  ...              0          0
# 520    2fmCon     2Story            4  ...            210          0
# 401      1Fam     1Story            7  ...              0          0
# 280      1Fam     2Story            7  ...              0        196
# 1401     1Fam     2Story            6  ...              0          0
#
#       ScreenPorch PoolArea PoolQC  Fence SaleType SaleCondition TotalSF  \
# 921             0        0    NaN  GdPrv       WD        Normal    3472
# 520             0        0    NaN    NaN       WD        Normal    1294
# 401             0        0    NaN    NaN      New       Partial    2620
# 280             0        0    NaN    NaN       WD        Normal    2789
# 1401            0        0    NaN    NaN       WD        Normal    2432
#
#      hasGarage
# 921          0
# 520          0
# 401          1
# 280          1
# 1401         1
#
# [5 rows x 62 columns]
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'TotalSF', 'hasGarage']
#       MSSubClass MSZoning  LotFrontage   LotArea Street Alley Utilities  \
# 921     0.411765       RL     0.157534  0.034948   Pave   NaN    AllPub
# 520     1.000000       RL     0.133562  0.044404   Pave  Grvl    AllPub
# 401     0.000000       RL     0.150685  0.034901   Pave   NaN    AllPub
# 280     0.235294       RL     0.208904  0.046680   Pave   NaN    AllPub
# 1401    0.235294       RL     0.140411  0.028582   Pave   NaN    AllPub
#
#      BldgType HouseStyle  OverallQual  ...  EnclosedPorch  3SsnPorch  \
# 921    Duplex     1.5Fin     0.444444  ...       0.000000   0.000000
# 520    2fmCon     2Story     0.333333  ...       0.380435   0.000000
# 401      1Fam     1Story     0.666667  ...       0.000000   0.000000
# 280      1Fam     2Story     0.666667  ...       0.000000   0.385827
# 1401     1Fam     2Story     0.555556  ...       0.000000   0.000000
#
#       ScreenPorch PoolArea PoolQC  Fence SaleType SaleCondition   TotalSF  \
# 921           0.0      0.0    NaN  GdPrv       WD        Normal  0.274829
# 520           0.0      0.0    NaN    NaN       WD        Normal  0.084078
# 401           0.0      0.0    NaN    NaN      New       Partial  0.200210
# 280           0.0      0.0    NaN    NaN       WD        Normal  0.215011
# 1401          0.0      0.0    NaN    NaN       WD        Normal  0.183745
#
#      hasGarage
# 921        0.0
# 520        0.0
# 401        1.0
# 280        1.0
# 1401       1.0
#
# [5 rows x 62 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import accuracy_score

print(train_x.head())
number_fields_not_null = []
number_fields_with_null = []
for col in train_x:
    if train_x.dtypes[col] in ["int64","float64"] and not train_x[col].isnull().values.any():
        number_fields_not_null.append(col)
    if train_x.dtypes[col] in ["int64","float64"] and train_x[col].isnull().values.any():
        number_fields_with_null.append(col)

print(number_fields_not_null)
print(number_fields_with_null)

model = GradientBoostingRegressor()
model.fit(train_x[number_fields_not_null], train_y)
predictions = model.predict(val_x[number_fields_not_null])



score = accuracy_score(val_y,predictions)
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street Alley Utilities  \
# 921     0.411765       RL     0.157534  0.034948   Pave   NaN    AllPub
# 520     1.000000       RL     0.133562  0.044404   Pave  Grvl    AllPub
# 401     0.000000       RL     0.150685  0.034901   Pave   NaN    AllPub
# 280     0.235294       RL     0.208904  0.046680   Pave   NaN    AllPub
# 1401    0.235294       RL     0.140411  0.028582   Pave   NaN    AllPub
#
#      BldgType HouseStyle  OverallQual  ...  EnclosedPorch  3SsnPorch  \
# 921    Duplex     1.5Fin     0.444444  ...       0.000000   0.000000
# 520    2fmCon     2Story     0.333333  ...       0.380435   0.000000
# 401      1Fam     1Story     0.666667  ...       0.000000   0.000000
# 280      1Fam     2Story     0.666667  ...       0.000000   0.385827
# 1401     1Fam     2Story     0.555556  ...       0.000000   0.000000
#
#       ScreenPorch PoolArea PoolQC  Fence SaleType SaleCondition   TotalSF  \
# 921           0.0      0.0    NaN  GdPrv       WD        Normal  0.274829
# 520           0.0      0.0    NaN    NaN       WD        Normal  0.084078
# 401           0.0      0.0    NaN    NaN      New       Partial  0.200210
# 280           0.0      0.0    NaN    NaN       WD        Normal  0.215011
# 1401          0.0      0.0    NaN    NaN       WD        Normal  0.183745
#
#      hasGarage
# 921        0.0
# 520        0.0
# 401        1.0
# 280        1.0
# 1401       1.0
#
# [5 rows x 62 columns]
# ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'TotalSF', 'hasGarage']
# ['LotFrontage', 'GarageYrBlt']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2056/4214896357.py in <module>
#      16 model = GradientBoostingRegressor()
#      17 model.fit(train_x[number_fields_not_null], train_y)
# ---> 18 predictions = model.predict(val_x[number_fields_not_null])
#      19
#      20 score = accuracy_score(val_y,predictions)
#
# c:\Users\jjoug\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# c:\Users\jjoug\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# c:\Users\jjoug\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['TotalSF', 'hasGarage'] not in index"
